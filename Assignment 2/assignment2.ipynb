# %% [markdown]
# # Assignment #2: Anonymous/Private Communications

# %% [markdown]
# Accessing website https://whatismyipaddress.com/ with regular browser

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Acessing website https://whatismyipaddress.com/ with Tor:

# %% [markdown]
# ![image.png](attachment:image.png)
